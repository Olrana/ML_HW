# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return 10*x-5

# %%
xs= np.linspace(0,10,20)
plt.plot(f(xs),xs, 'o');

# %%
def f_d(x):
    return np.full_like(x, 10)

# %%
plt.plot(xs_d, f(xs_d), 'o');

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
x = sp.Symbol('x')
f1 = sp.sin(x)
f2 = sp.log(x)

df1 = sp.diff(f1, x)  # cos(x)
df2 = sp.diff(f2, x)  # 1/x

f1_func = sp.lambdify(x, f1, 'numpy')
df1_func = sp.lambdify(x, df1, 'numpy')

f2_func = sp.lambdify(x, f2, 'numpy')
df2_func = sp.lambdify(x, df2, 'numpy')

x_vals = np.linspace(0.1, 10, 400)  

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(x_vals, f1_func(x_vals), label='f(x) = sin(x)', color='blue')
plt.plot(x_vals, df1_func(x_vals), label="f'(x) = cos(x)", color='green', linestyle='--')
plt.title('Синус і його похідна')
plt.xlabel('x')
plt.ylabel('Значення')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(x_vals, f2_func(x_vals), label='f(x) = ln(x)', color='purple')
plt.plot(x_vals, df2_func(x_vals), label="f'(x) = 1/x", color='orange', linestyle='--')
plt.title('Логарифм і його похідна')
plt.xlabel('x')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
x = sp.Symbol('x')
f = (1/3)*x**3 - 5*x + 1

f_derivative = sp.diff(f, x)
f_derivative_func = sp.lambdify(x, f_derivative, 'numpy')

x_values = np.arange(1, 101)  # x від 1 до 100
y_derivative_values = [f_derivative_func(i) for i in x_values]  

plt.figure(figsize=(8,5))
plt.plot(x_values, y_derivative_values, label="f'(x)")
plt.xlabel("x")
plt.ylabel("f'(x)")
plt.title("Графік похідної")
plt.grid(True)
plt.legend()
plt.show()
